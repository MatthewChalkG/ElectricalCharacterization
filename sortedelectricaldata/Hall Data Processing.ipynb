# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def avgHallSignal(data):
    dcList = data['trueGateDC'].unique()
    dataP = data[data['i'] == 3.2]
    dataN = data[data['i'] == -3.2]
    avgP = []
    avgN = []

    for dc in dcList:
        dataDC = dataP[abs(dataP['trueGateDC'] - dc) < .1]
        avgX = np.mean(dataDC['x'])
        avgP += [avgX]
                  
    for dc in dcList:
        dataDC = dataN[abs(dataN['trueGateDC'] - dc) < .1]
        avgX = np.mean(dataDC['x'])
        #linOffset = (list(dataDC['x'])[-1]-list(dataDC['x'])[0])/(len(dataDC)*2)
        #linOffset = 0
        linOffset = 0
        avgN += [avgX-linOffset]
    
    avgDiff = [avgP[i]-avgN[i] for i in range(len(avgP))]
    return avgDiff

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1707417140.txt")
g1 = avgHallSignal(data)
plt.scatter(dcList1, g1, color = 'green')

plt.title("Hall Voltage")
plt.ylabel("Difference in Hall Voltages at Min and Max Field (V)")
plt.xlabel("Gate Voltage (V)")
# Out:
# Text(0.5, 0, 'Gate Voltage (V)')

# %%
data = pd.read_csv("datalogging/Data/HallEffectDCBias/hallDCBiasSMU1707417140.txt")
plt.scatter(data['trueGateDC'], data['trueGateDC']/data['trueGateI'], color = 'greY')
plt.title("Gate Leakage")
plt.xlabel('Gate Voltage (V)')
plt.ylabel('Gate Resistance ($\Omega$)')
# Out:
# Text(0, 0.5, 'Gate Resistance ($\\Omega$)')

# %%
data
# Out:
#                 t    i             x             y             r      theta  \
# 0    1.707417e+09  3.2  2.489421e-08  5.738173e-09  2.810574e-08   12.98010
# 1    1.707417e+09 -3.2 -1.897529e-08  1.304649e-08  2.690588e-08  153.60420
# 2    1.707417e+09  3.2  1.758262e-08  1.304649e-08  2.189428e-08   18.07434
# 3    1.707417e+09 -3.2 -4.091004e-08  5.738173e-09  4.293999e-08  173.21390
# 4    1.707417e+09  3.2 -4.352126e-09  5.738173e-09  1.375325e-08   51.78788
# ..            ...  ...           ...           ...           ...        ...
# 415  1.707421e+09 -3.2  9.069846e-08 -2.349507e-08  9.213154e-08  350.62200
# 416  1.707421e+09  3.2  1.272564e-07 -3.080338e-08  1.210321e-07  355.76660
# 417  1.707421e+09 -3.2  9.801004e-08 -2.349507e-08  9.213154e-08  345.47700
# 418  1.707421e+09  3.2  1.272564e-07 -1.618676e-08  1.202729e-07  355.76660
# 419  1.707421e+09 -3.2  7.607530e-08 -1.618676e-08  9.213154e-08  358.92130
#
#      xK  tc  therm  trueGateDC     trueGateI            x2            y2  \
# 0     0   0      0    0.000020 -2.637557e-10 -2.384200e-07  0.000000e+00
# 1     0   0      0    0.000020 -2.637557e-10  0.000000e+00  0.000000e+00
# 2     0   0      0    0.000020 -2.637557e-10  0.000000e+00 -2.384200e-07
# 3     0   0      0    0.000020 -2.637557e-10  0.000000e+00 -2.384200e-07
# 4     0   0      0    0.000020 -2.637557e-10  0.000000e+00  0.000000e+00
# ..   ..  ..    ...         ...           ...           ...           ...
# 415   0   0      0    0.000011 -1.113335e-09  0.000000e+00  0.000000e+00
# 416   0   0      0    0.000011 -1.113335e-09  0.000000e+00 -2.384200e-07
# 417   0   0      0    0.000011 -1.113335e-09  0.000000e+00  0.000000e+00
# 418   0   0      0    0.000011 -1.113335e-09  0.000000e+00  0.000000e+00
# 419   0   0      0    0.000011 -1.113335e-09  0.000000e+00 -2.384200e-07
#
#            r2  theta2
# 0   -0.002832   135.0
# 1   -0.002832    90.0
# 2   -0.002832   -90.0
# 3   -0.002832   -90.0
# 4   -0.002832    90.0
# ..        ...     ...
# 415 -0.002832     0.0
# 416 -0.002832   -45.0
# 417 -0.002832    90.0
# 418 -0.002832     0.0
# 419 -0.002832   -90.0
#
# [420 rows x 15 columns]
