# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def evenOdd(data):
    even = []
    odd = []
    for i in range(len(data['x'])):
        if i % 2 == 0:
            even += [list(data['x'])[i]]
        elif i % 2 == 1:
            odd += [list(data['x'])[i]]
    diff = [even[i] - odd[i] for i in range(len(odd))]
    return even, odd, diff

# %%
def splitByCurrent(data):
    iData = list(data['i'])
    xData = list(data['x'])
    tData = list(data['t'])
    
    posCurrX = []
    negCurrX = []
    
    posCurrT = []
    negCurrT = []
    

    for j in range(len(iData)):
        if iData[j] > 0:
            posCurrX  += [xData[j]]
            posCurrT += [tData[j]]
        else:
            negCurrX += [xData[j]]
            negCurrT += [tData[j]]

    return posCurrX, negCurrX, posCurrT, negCurrT

def diffTwo(data):
    posCurrX, negCurrX, posCurrT, negCurrT = splitByCurrent(data)
    if len(posCurrX) > len(negCurrX):
        posCurrX = posCurrX[1:]
        posCurrT = posCurrT[1:]
    elif len(posCurrX) < len(negCurrX):
        negCurrX = negCurrX[1:]
        negCurrT = negCurrT[1:]
    
    diffX = [posCurrX[i] - negCurrX[i] for i in range(len(negCurrX))]
    offX = [(posCurrX[i] + negCurrX[i])/2 for i in range(len(negCurrX))]
    avgT = [(posCurrT[i] + negCurrT[i])/2 for i in range(len(negCurrX))]
    return avgT, diffX, offX

# %%
d1 = data.copy()
d2 = data.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6136\4186935804.py in <module>
# ----> 1 d1 = data.copy()
#       2 d2 = data.copy()
#
# NameError: name 'data' is not defined

# %%
d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)

# %%
data = pd.read_csv("datalogging/hallDCBias.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)

plt.scatter(d1['dc'], d1['x'])
plt.scatter(d2['dc'], d2['x'])

# %%
data = pd.read_csv("datalogging/hallDCBias.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)

plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/hallDCBias.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


plt.scatter(d1['dc'], d1['x'])
plt.scatter(d2['dc'], d2['x'])
#plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6136\2040445011.py in <module>
# ----> 1 data = pd.read_csv("datalogging/hallDCBias.txt")
#       2
#       3 d1 = data.copy()
#       4 d2 = data.copy()
#       5
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/hallDCBias.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


plt.scatter(d1['dc'], d1['x'])
plt.scatter(d2['dc'], d2['x'])
#plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data = pd.read_csv("datalogging/hallDCBias.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])
#plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/hallDCBias.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])
#plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19120\820664874.py in <module>
# ----> 1 data = pd.read_csv("datalogging/hallDCBias.txt")
#       2
#       3 d1 = data.copy()
#       4 d2 = data.copy()
#       5
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8583951.txt")
plt.scatter(data['t'][1:], data['x'][1:])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8584111.txt") # slow B scan
plt.scatter(data['t'][1:], data['x'][1:])

# %%
plt.scatter(data['i'][1:], data['x'][1:])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8584549.txt") # slow B scan
plt.scatter(data['t'], data['x']) 
plt.title("slow B field sweep: 0 G --> 53.1 G -- > 0 G --> -53.1 G -- > 0G")
plt.xlabel("time")
plt.ylabel("Hall Voltage w/ offset")
# Out:
# Text(0, 0.5, 'Hall Voltage w/ offset')

# %%
b = [data['i'][i] * 16.6 for i in range(len(data['i']))]
plt.scatter(b, data['x'])  
plt.title("magn field vs Hall Voltage w/ offset (ignore sign), 2.5 V input voltage (i think)")
plt.xlabel("magn field (gauss)")
plt.ylabel("Hall Voltage w/ offset (V)")
a1, b1 = np.polyfit(b, data['x'], 1)
plt.plot(b, [a1*list(b)[i]+b1 for i in range(len(b))], label = "offset = -1.05*10^-6, slope = -.0018")
plt.legend()

# %%
b1
# Out:
# -0.0017665067749999925

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8584923.txt") # slow B scan
data
# Out:
#                 t    i         x         y             r      theta  xK  tc  \
# 0    1.678585e+09  3.2 -0.000039 -0.000677  3.391842e-07  265.23610   0   0
# 1    1.678585e+09 -3.2  0.000020 -0.000648  3.208092e-07  274.00590   0   0
# 2    1.678585e+09  3.2 -0.000090 -0.000666  3.475629e-07  261.43090   0   0
# 3    1.678585e+09 -3.2 -0.000028 -0.000637  3.183394e-07  270.13400   0   0
# 4    1.678585e+09  3.2 -0.000086 -0.000662  3.346435e-07  261.02890   0   0
# ..            ...  ...       ...       ...           ...        ...  ..  ..
# 145  1.678586e+09 -3.2  0.000407  0.001143  6.049590e-07   70.27100   0   0
# 146  1.678586e+09  3.2 -0.000009  0.001143  5.751745e-07   90.84747   0   0
# 147  1.678586e+09 -3.2 -0.000002  0.001143  5.751425e-07   89.92628   0   0
# 148  1.678586e+09  3.2 -0.000017  0.001150  5.770015e-07   91.01875   0   0
# 149  1.678586e+09 -3.2 -0.000017  0.001154  6.484315e-07  135.63170   0   0
#
#      therm         dc
# 0        0  -0.000000
# ...

# %%
d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


#plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])
plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
[list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))]
# Out:
# [-5.8492665e-05,
#  -6.2148445e-05,
#  -5.1181064999999994e-05,
#  -5.849264499999999e-05,
#  -0.00010236199999999994,
#  -0.000347300195,
#  -0.0005483687000000001,
#  -0.00019741274999999998,
#  -6.946e-05,
#  -0.00016451065000000001,
#  -0.0008408318999998999,
#  -0.0027674344499999,
#  -0.0005227780000001,
#  -0.0003217094999999001,
#  -0.00168166435,
#  -0.0001169853285,
#  -5.849267e-05,
#  1.4623164999999997e-05,
#  -0.00058858245,
#  -0.00032902125000000006,
#  -2.1934750000000002e-05,
#  0.00142941427,
#  -0.00130877323,
#  -0.0044161955,
#  0.0021898191499999,
#  -0.0079184445,
#  -0.0009212595,
#  2.1934770000000003e-05,
#  -0.00023397065,
#  -3.2902122e-05,
#  0.0001060179699999,
#  0.0030379631050000003,
#  -0.00628430595,
#  -1.4623149999900019e-05,
#  -3.290209999999999e-05,
#  -7.3115849999999985e-06,
#  -0.0004021371,
#  -6.58042500001e-05,
#  0.000109673755,
#  -7.3115855e-05,
#  -6.580422999999998e-05,
#  2.924633e-05,
#  -8.042741300000001e-05,
#  -2.9246335e-05,
# ...

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8586220.txt") # slow B scan

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


#plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])
plt.scatter(d1['dc'][:-1], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x'])-1)])

# %%
data
# Out:
#                t    i         x         y             r      theta  xK  tc  \
# 0   1.678586e+09  3.2  0.000338  0.007165  3.577067e-06   89.63718   0   0
# 1   1.678586e+09 -3.2  0.000206  0.000017  1.581872e-07  324.62330   0   0
# 2   1.678586e+09  3.2  0.000473 -0.000067  2.179692e-07  321.90090   0   0
# 3   1.678586e+09 -3.2  0.000356  0.000313  2.069257e-07  358.42690   0   0
# 4   1.678586e+09  3.2  0.001146  0.000200  6.130700e-07  357.35450   0   0
# ..           ...  ...       ...       ...           ...        ...  ..  ..
# 70  1.678587e+09  3.2  0.000879  0.000387  3.556014e-07  301.95430   0   0
# 71  1.678587e+09 -3.2 -0.000496  0.001212  6.847525e-07   77.99530   0   0
# 72  1.678587e+09  3.2 -0.007387  0.000664  3.118757e-06  157.93520   0   0
# 73  1.678587e+09 -3.2 -0.005204  0.000701  2.767259e-06  168.32040   0   0
# 74  1.678587e+09  3.2  0.007156  0.000960  3.168646e-06   34.38211   0   0
#
#     therm        dc
# 0       0  0.000000
# 1       0  0.000000
# ...

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8586742.txt") # slow B scan
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8587930.txt") # slow B scan
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8588130.txt") # slow B scan
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8588605.txt") # slow B scan

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


plt.scatter(d1['dc'], d1['x'])
plt.scatter(d2['dc'], d2['x'])
plt.scatter(d1['dc'][:-1], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x'])-1)])

# %%
dataa = pd.read_csv("datalogging/Data/hallDCBias8589778.txt") # slow B scan

d1a = dataa.copy()
d2a = dataa.copy()

d1a = d1a.drop(d1a[d1a.i < 0].index)
d2a = d2a.drop(d1a[d1a.i > 0].index)


plt.scatter(d1a['dc'], d1a['x'])
plt.scatter(d2a['dc'], d2a['x'])
plt.scatter(d1a['dc'], [list(d1a['x'])[i]-list(d2a['x'])[i] for i in range(len(d1a['x']))])

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8590850.txt") # slow B scan

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


plt.scatter(d1['dc'], d1['x'])
plt.scatter(d2['dc'], d2['x'])
plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8593736.txt") # slow B scan

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


plt.scatter(d1['dc'], d1['x'])
plt.scatter(d2['dc'], d2['x'])
plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8594987.txt") # slow B scan
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8595254.txt") # slow B scan
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8595505.txt") # slow B scan
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8595622.txt") # slow B scan
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8693577.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8693787.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8694629.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8695268.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8695592.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8695688.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8695818.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8695954.txt") # forgot to change neg sign

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)

revd1 = [list(d1['x'])[i]*-1 for i in range(len(d1['x']))]
revd2 = [list(d2['x'])[i]*-1 for i in range(len(d2['x']))]

plt.scatter(d1['dc'], revd1)
plt.scatter(d2['dc'], revd2)
plt.scatter(d1['dc'], [revd1[i]-revd2[i] for i in range(len(d1['x']))])

# %%
len(d1a['x'])
# Out:
# 75

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8696943.txt") # forgot to change neg sign

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)

revd1 = [list(d1['x'])[i]*-1 for i in range(len(d1['x']))]
revd2 = [list(d2['x'])[i]*-1 for i in range(len(d2['x']))]

plt.scatter(d1['dc'], revd1)
plt.scatter(d2['dc'], revd2)
plt.scatter(d1['dc'], [revd1[i]-revd2[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8697900.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)

revd1 = [list(d1['x'])[i] for i in range(len(d1['x']))]
revd2 = [list(d2['x'])[i] for i in range(len(d2['x']))]

plt.scatter(d1['dc'], revd1)
plt.scatter(d2['dc'], revd2)
plt.scatter(d1['dc'], [revd1[i]-revd2[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8698024.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8698131.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)

revd1 = [list(d1['x'])[i] for i in range(len(d1['x']))]
revd2 = [list(d2['x'])[i] for i in range(len(d2['x']))]

#plt.scatter(d1['dc'], revd1)
#plt.scatter(d2['dc'], revd2)
plt.scatter(d1['dc'], [revd1[i]-revd2[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8698727.txt") 
plt.scatter(data['t'], data['x'])

# %%
data
# Out:
#               t    i         x         y         r     theta  xK  tc   therm
# 0  1.678699e+09  3.2 -0.021905 -0.012805  0.000253  210.1669   0   0       0
# 1  1.678699e+09 -3.2 -0.021759 -0.012805  0.000252  210.4771   0   0       0
# 2  1.678699e+09  3.2 -0.021832 -0.012732  0.000253  210.2502   0   0       0
# 3  1.678699e+09 -3.2 -0.021686 -0.012878  0.000252  210.5614   0   0       0
# 4  1.678699e+09  3.2 -0.021759 -0.012732  0.000252  210.1069   0   0       0
# 5  1.678699e+09 -3.2 -0.021686 -0.012805  0.000252  210.5614   0   0       0
# 6  1.678699e+09  3.2 -0.021759 -0.012659  0.000253  210.2502   0   0       0
# 7  1.678699e+09 -3.2 -0.021759 -0.012805  0.000252  210.6198   0   0       0
# 8  1.678699e+09  3.2 -0.021832 -0.012732  0.000252  210.1069   0   0       0
# 9  1.678699e+09 -3.2 -0.021759 -0.012732  0.000253  210.4771   0   0       0

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8698823.txt") 
plt.scatter(data['t'], data['x'])

# %%
data['x']
# Out:
# 0     0.000015
# 1     0.000015
# 2    -0.000095
# 3     0.000015
# 4    -0.000058
# 5     0.000051
# 6    -0.000058
# 7     0.000051
# 8    -0.000058
# 9     0.000051
# 10   -0.000058
# 11    0.000051
# Name: x, dtype: float64

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8703116.txt") # slow B scan

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


#plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])
plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
data = pd.read_csv("datalogging/Data/hallVoltageSweep8704443.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8704941.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)
d2 = d2.drop(d1[d1.i > 0].index)


plt.scatter(d1['dc'], d1['x'])
plt.scatter(d2['dc'], d2['x'])
diff1=[list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))]
plt.scatter(d1['dc'], diff1)
d11 = d1['dc']

# %%
d1
# Out:
#                 t    i         x         y         r      theta  xK  tc  \
# 0    1.678705e+09  3.2 -0.000140  0.001868  0.000004   94.26289   0   0
# 2    1.678705e+09  3.2  0.007683 -0.008335  0.000023  312.56630   0   0
# 4    1.678705e+09  3.2  0.009774 -0.016286  0.000038  301.22180   0   0
# 6    1.678705e+09  3.2  0.010695 -0.015643  0.000037  304.49090   0   0
# 8    1.678705e+09  3.2  0.010359 -0.015862  0.000038  302.87030   0   0
# ..            ...  ...       ...       ...       ...        ...  ..  ..
# 120  1.678706e+09  3.2 -0.019224  0.022229  0.000059  130.81030   0   0
# 122  1.678706e+09  3.2 -0.019355  0.022346  0.000059  130.91090   0   0
# 124  1.678706e+09  3.2 -0.019458  0.022463  0.000059  130.92100   0   0
# 126  1.678706e+09  3.2 -0.019575  0.022594  0.000060  130.90120   0   0
# 128  1.678706e+09  3.2 -0.019677  0.022696  0.000060  130.92390   0   0
#
#      therm    dc
# 0        0   0.0
# 2        0   0.5
# 4        0   1.0
# 6        0   1.5
# ...

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8706209.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)[:-1]
d2 = d2.drop(d1[d1.i > 0].index)


#plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])
plt.scatter(d1['dc'], [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))])

# %%
d2
# Out:
#                t    i         x             y             r     theta  xK  tc  \
# 1   1.678706e+09 -3.2 -0.000039  3.210233e-05  2.658690e-08  139.8518   0   0
# 3   1.678706e+09 -3.2 -0.000006 -7.850685e-07  2.471941e-09  280.3611   0   0
# 5   1.678706e+09 -3.2  0.000031 -3.732662e-05  2.455719e-08  312.6484   0   0
# 7   1.678706e+09 -3.2  0.000049 -6.290570e-05  4.101917e-08  309.5930   0   0
# 9   1.678706e+09 -3.2  0.000071 -8.483065e-05  5.786635e-08  308.7198   0   0
# 11  1.678706e+09 -3.2  0.000111 -1.213722e-04  8.487160e-08  311.5309   0   0
# 13  1.678706e+09 -3.2  0.000144 -1.542596e-04  1.068746e-07  313.7266   0   0
# 15  1.678706e+09 -3.2  0.000166 -1.798387e-04  1.223670e-07  313.9169   0   0
# 17  1.678706e+09 -3.2  0.000210 -2.236885e-04  1.533004e-07  313.6671   0   0
# 19  1.678706e+09 -3.2  0.000246 -2.529218e-04  1.778714e-07  313.8430   0   0
# 21  1.678706e+09 -3.2  0.000276 -2.785009e-04  1.959592e-07  314.3421   0   0
# ...

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8706799.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)[:-1]
d2 = d2.drop(d1[d1.i > 0].index)


#plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])

diff = [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))]
plt.scatter(d1['dc'], diff)

# %%
diff
# Out:
# [-0.00011698533999999999,
#  -0.0001316086,
#  -0.00011698533999999998,
#  -7.311599999999991e-05,
#  -2.9246199999999984e-05,
#  1.462200000000016e-05,
#  -8.77380000000004e-05,
#  -0.00010236199999990019,
#  -8.774000000000021e-05,
#  -0.00010236199999999994,
#  -8.773800000009928e-05,
#  -5.8492000000000266e-05,
#  -5.8492000000000266e-05,
#  -5.8492000000000266e-05,
#  -5.849400000000095e-05,
#  -8.77380000000004e-05,
#  -7.311599999990093e-05,
#  -5.8492000000000266e-05,
#  -4.386999999999967e-05,
#  -4.386999999999967e-05,
#  -0.00010236200000000167,
#  0.007267713999999901,
#  -0.003992126,
#  0.0009505060000000003,
#  -0.0006287960000000998]

# %%
diff1
# Out:
# [-7.311582e-05,
#  -4.3868000000099605e-05,
#  -0.0010382440000000007,
#  -0.00019010000000000034,
#  -0.002339708000000001,
#  -2.9246000000000133e-05,
#  -0.00036557999999999903,
#  -0.0006872879999999994,
#  1.4622000000000593e-05,
#  -4.386999999999967e-05,
#  0.0013307079999999999,
#  -0.00013160999999999902,
#  0.0013014600000000008,
#  -8.77380000000004e-05,
#  -7.31159999999998e-05,
#  0.00045331800000000116,
#  0.02678964,
#  -0.00020472399999999988,
#  -0.00017547799999999975,
#  -0.00013160800000000007,
#  -0.00010236199999999994,
#  -0.00016085399999999847,
#  -0.0001462319999999996,
#  -0.00013160800000000007,
#  -0.00011698800000000016,
#  -0.00010236199999989933,
#  -0.00016085599999999915,
#  -0.00013160800000000007,
#  -0.00013160999999999902,
#  -0.0001316100000000979,
#  -0.00016085399999999847,
#  -0.00026321800000000256,
#  -0.0001462319999999996,
#  -0.0001316100000000979,
#  -0.00013160799999999834,
#  -0.00014623000000000067,
#  -0.00013160799999999834,
# ...

# %%
plt.scatter(d11, diff1)
plt.scatter(d1['dc'], diff)
plt.ylim([-.0003, .0001])
# Out:
# (-0.0003, 0.0001)

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8708109.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)[:-1]
d2 = d2.drop(d1[d1.i > 0].index)


#plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])

diff = [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))]
plt.scatter(d1['dc'], diff, color = 'green')
plt.scatter(d11, diff1, color = 'green')

plt.ylim([-.0003, .0003])
#plt.xlim([-20, -10])
plt.title("Jank scan, 33 celsius, temp control died on neg sweep")
plt.xlabel("bias voltage (V)")
plt.ylabel("Hall Voltage (V)")
# Out:
# Text(0, 0.5, 'Hall Voltage (V)')

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8710756.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)[:-1]
d2 = d2.drop(d1[d1.i > 0].index)


#plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])

diff = [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))]
plt.scatter(d1['dc'], diff, color = 'green')

# %%
data = pd.read_csv("datalogging/Data/hallDCBias8711594.txt")

d1 = data.copy()
d2 = data.copy()

d1 = d1.drop(d1[d1.i < 0].index)[:-1]
d2 = d2.drop(d1[d1.i > 0].index)


#plt.scatter(d1['dc'], d1['x'])
#plt.scatter(d2['dc'], d2['x'])

diff = [list(d1['x'])[i]-list(d2['x'])[i] for i in range(len(d1['x']))]
plt.scatter(d1['dc'], diff, color = 'green')

# %%
d1
# Out:
#                t    i         x         y             r     theta  xK  tc  \
# 0   1.678712e+09  3.2  0.000111 -0.000213  1.216301e-07  296.4182   0   0
# 2   1.678712e+09  3.2  0.000181 -0.000220  1.400435e-07  307.1768   0   0
# 4   1.678712e+09  3.2  0.000224 -0.000216  1.623372e-07  317.8563   0   0
# 6   1.678712e+09  3.2  0.000283 -0.000220  1.800724e-07  320.4873   0   0
# 8   1.678712e+09  3.2  0.000254 -0.000224  1.637134e-07  319.4734   0   0
# 10  1.678712e+09  3.2  0.000780 -0.000231  4.003477e-07  342.9588   0   0
# 12  1.678712e+09  3.2  0.000842 -0.000227  4.349435e-07  344.8956   0   0
# 14  1.678712e+09  3.2  0.000831 -0.000231  4.296592e-07  344.5109   0   0
# 16  1.678712e+09  3.2  0.000868 -0.000242  4.482498e-07  344.9315   0   0
# 18  1.678712e+09  3.2  0.000850 -0.000216  4.321618e-07  346.3653   0   0
# 20  1.678712e+09  3.2  0.000488 -0.000227  2.673871e-07  334.8418   0   0
# 22  1.678712e+09  3.2  0.000491 -0.000235  2.756870e-07  335.6493   0   0
# ...

# %%
data = pd.read_csv("datalogging/Data/resistivity8917618.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity8919147.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity8922232.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity8922865.txt") 
plt.scatter(data['dc'], data['x']/(-.273*10**-3), color = 'brown') 
data2 = pd.read_csv("datalogging/Data/resistivity8923936.txt") 
plt.scatter(data2['dc'], data2['x']/(-.273*10**-3), color = 'brown') 
plt.xlabel('dc bias (V)')
plt.ylabel('resistivity')
plt.title('jank circuitry, 33 celsius')
# Out:
# Text(0.5, 1.0, 'jank circuitry, 33 celsius')

# %%
data2 = pd.read_csv("datalogging/Data/resistivity8925526.txt") 
data2['dc'] = [data2['dc'][i]*-1 for i in range(len(data2['dc']))]
plt.scatter(data2['dc'], data2['x']/(-.273*10**-3))



data3 = pd.read_csv("datalogging/Data/resistivity8924860.txt") 
plt.scatter(data3['dc'], data3['x']/(-.273*10**-3))

plt.xlabel('dc bias (V)')
plt.ylabel('resistivity')
plt.title('jank circuitry, 33 celsius')
plt.axvline(-.35)

# %%
data3 = pd.read_csv("datalogging/Data/resistivity8927131.txt") 
plt.scatter(data3['dc'], data3['x']/(-.273*10**-3))

# %%
data3 = pd.read_csv("datalogging/Data/resistivity8927854.txt") 
plt.scatter(data3['dc'], data3['x']/(-.273*10**-3))

# %%
data3 = pd.read_csv("datalogging/Data/resistivity8928256.txt") 
plt.scatter(data3['dc'], data3['x']/(-.273*10**-3))

# %%
data3 = pd.read_csv("datalogging/Data/resistivity8928918.txt") 
plt.scatter(data3['dc'], data3['x']/(-.273*10**-3))

plt.xlabel('dc bias (V)')
plt.ylabel('resistivity')
plt.title('jank circuitry (so resistance not the exact same depending on which way measuring), 33 celsius, dirac point approx -.35 V')
plt.axvline(-.35)

# %%
data = pd.read_csv("datalogging/Data/resistivity8927131.txt") 
plt.scatter(data['dc'], data['x']/(-.273*10**-3))

data3 = pd.read_csv("datalogging/Data/resistivity8929604.txt") 
plt.scatter(data3['dc'], data3['x']/(-.273*10**-3))

plt.xlabel('dc bias (V)')
plt.ylabel('resistivity')
plt.title('jank circuitry (so resistance not the exact same depending on which way measuring), 33 celsius, dirac point approx -.35 V')
plt.axvline(-.35)

# %%
data = pd.read_csv("datalogging/Data/resistivity8930520.txt") 
plt.scatter(data['dc'], data['x']/(-.273*10**-3))

data3 = pd.read_csv("datalogging/Data/resistivity8928918.txt") 
plt.scatter(data3['dc'], data3['x']/(-.273*10**-3))

plt.xlabel('dc bias (V)')
plt.ylabel('resistivity')
plt.title('jank circuitry (so resistance not the exact same depending on which way measuring), 33 celsius, dirac point approx -.35 V')
plt.axvline(-.35)

# %%
data = pd.read_csv("datalogging/Data/resistivity9354865.txt") 
plt.scatter(data['dc'], data['x']/(-.273*10**-3))

# %%
data = pd.read_csv("datalogging/Data/resistivity9355916.txt") 
plt.scatter(data['dc'], data['x']/(-.273*10**-3))

# %%
data = pd.read_csv("datalogging/Data/resistivity9360647.txt") 
plt.scatter(data['dc'], data['x']/(-.273*10**-3))

# %%
data = pd.read_csv("datalogging/Data/resistivity9437326.txt") 
plt.scatter(data['dc'], data['x']/(10**-4))

# %%
data = pd.read_csv("datalogging/Data/resistivity9438252.txt") 
plt.scatter(data['dc'], data['x']/(10**-4))

# %%
data = pd.read_csv("datalogging/Data/resistivity9439172.txt") 
plt.scatter(data['dc'], data['x']/(10**-4))

# %%
data = pd.read_csv("datalogging/Data/resistivity9438252.txt") 
plt.scatter(data['dc'], data['x']/(10**-4))
data = pd.read_csv("datalogging/Data/resistivity9439172.txt") 
plt.scatter(data['dc'], data['x']/(10**-4))

# %%
data = pd.read_csv("datalogging/Data/resistivity9439980.txt") 
plt.scatter(data['dc'], data['x']/(10**-4))
data = pd.read_csv("datalogging/Data/resistivity9439172.txt") 
plt.scatter(data['dc'], data['x']/(10**-4))

# %%
data = pd.read_csv("datalogging/Data/resistivity9439980.txt") 
plt.scatter(data['dc'], data['theta'])
data = pd.read_csv("datalogging/Data/resistivity9439172.txt") 
plt.scatter(data['dc'], data['theta'])

# %%
data
# Out:
#                 t  i         x         y         r     theta  xK  tc  therm  \
# 0    1.679439e+09  0  0.100082 -0.010702  0.002013  353.9707   0   0      0
# 1    1.679439e+09  0  0.099643 -0.010994  0.002005  353.7039   0   0      0
# 2    1.679439e+09  0  0.099643 -0.010994  0.002002  353.7039   0   0      0
# 3    1.679439e+09  0  0.099204 -0.011140  0.001997  353.6763   0   0      0
# 4    1.679439e+09  0  0.099204 -0.011140  0.001997  353.5000   0   0      0
# ..            ... ..       ...       ...       ...       ...  ..  ..    ...
# 146  1.679440e+09  0  0.115436 -0.014210  0.002323  353.0088   0   0      0
# 147  1.679440e+09  0  0.115728 -0.014210  0.002326  353.0540   0   0      0
# 148  1.679440e+09  0  0.116021 -0.013917  0.002340  353.2394   0   0      0
# 149  1.679440e+09  0  0.116460 -0.013479  0.002345  353.1768   0   0      0
# 150  1.679440e+09  0  0.116460 -0.013771  0.002345  352.7682   0   0      0
#
#        dc
# 0     0.0
# 1     0.2
# 2     0.4
# ...

# %%
data = pd.read_csv("datalogging/Data/resistivity9443082.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9444310.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9446373.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9446910.txt") 
plt.scatter(data['t'], data['x']/10**-4)

# %%
data = pd.read_csv("datalogging/Data/resistivity9698486.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9699873.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9702206.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9702206.txt") 
plt.scatter(data['dc'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity9703047.txt") 
plt.scatter(data['dc'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity9704100.txt") 
plt.scatter(data['dc'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity9704944.txt") 
plt.scatter(data['dc'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity9705694.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9704944.txt") 
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9705694.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9960888.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9961568.txt") 
plt.scatter(data['dc'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity9962617.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9963459.txt") 
plt.scatter(data['dc'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity9963890.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity9964300.txt") 
plt.scatter(data['dc'], data['x'])

# %%
##### sample 2 (2 broken contacts):
# 2.51 V input, 100 KOhm load -- > curr is
curr = 2.51/10**5

# %%
data = pd.read_csv("datalogging/Data/resistivity0041238.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity0041579.txt") 
plt.scatter(data['dc'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity0042126.txt") 
plt.scatter(data['dc'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity0042126.txt") 
plt.scatter(data['t'], data['x'])
#plt.scatter(data['t'], data['dc'])

# %%
data = pd.read_csv("datalogging/Data/resistivity0042691.txt") 
plt.scatter(data['dc'], data['x'])
#plt.scatter(data['t'], data['dc'])

# %%
data = pd.read_csv("datalogging/Data/resistivity0043040.txt") 
plt.scatter(data['dc'], data['x'])
#plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity0043040.txt") 
plt.scatter(data['dc'], data['x'])
#plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity0043718.txt") 
plt.scatter(data['dc'], data['x'])
#plt.scatter(data['t'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity0044384.txt") 
plt.scatter(data['dc'], data['x'])
#plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/resistivity0044384.txt") 
plt.scatter(data['t'], data['x'])
#plt.scatter(data['t'], data['x'])

# %%
##### sample 2 (2 broken contacts):
# 1.8 V input, 100 KOhm load -- > curr is
curr = 1.8/10**5

data = pd.read_csv("datalogging/Data/resistivity0043718.txt") 
plt.scatter(data['dc'], data['x']/curr)
#plt.scatter(data['t'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity0045012.txt") 
plt.scatter(data['dc'], data['x']/(curr))
#plt.scatter(data['t'], data['x'])
plt.ylabel("resistance (ohms)")
plt.xlabel("DC Bias (V)")
plt.title("device 2 (faulty), 2khz")
# Out:
# Text(0.5, 1.0, 'device 2 (faulty), 2khz')

# %%
##### sample 3 (0 broken contacts):
# 2.5 V input, 100 KOhm load -- > curr is
curr = 2.5/10**5

data = pd.read_csv("datalogging/Data/resistivity0051107.txt") 
plt.scatter(data['dc'], data['x']/curr)
#plt.scatter(data['t'], data['x'])
data = pd.read_csv("datalogging/Data/resistivity0051655.txt") 
plt.scatter(data['dc'], data['x']/(curr))

data = pd.read_csv("datalogging/Data/resistivity0052496.txt") 
plt.scatter(data['dc'], data['x']/(curr))

data = pd.read_csv("datalogging/Data/resistivity0053118.txt") 
plt.scatter(data['dc'], data['x']/(curr))

data = pd.read_csv("datalogging/Data/resistivity1680117728.txt") 
plt.scatter(data['dc'], data['x']/(curr))

#plt.scatter(data['t'], data['x'])
plt.ylabel("resistance (ohms)")
plt.xlabel("DC Bias (V)")
plt.title("device 3, 2khz")
data = pd.read_csv("datalogging/Data/ResistivityDCBias/resistivity1680118870.txt") 
plt.scatter(data['dc'], data['x']/(curr))

data = pd.read_csv("datalogging/Data/ResistivityDCBias/resistivity1680121500.txt") 
plt.scatter(data['dc'], data['x']/(curr))

data = pd.read_csv("datalogging/Data/ResistivityDCBias/resistivity1680122697.txt") 
plt.scatter(data['dc'], data['x']/(curr))

#plt.xlim(30, 60)

# %%
data = pd.read_csv("datalogging/Data/ResistivityDCBias/resistivity1680122697.txt") 
plt.scatter(data['dc'], data['x']/(curr))

# %%
data = pd.read_csv("datalogging/Data/Resistivity/resistivity1680125787.txt")
plt.scatter(data['t'], data['x']/(curr))

# %%
data = pd.read_csv("datalogging/Data/HallSweep/hallSweep1680126420.txt")
plt.scatter(data['i'], data['x'])

# %%
data['x']
# Out:
# 0    -0.000023
# 1    -0.000024
# 2    -0.000020
# 3    -0.000021
# 4    -0.000018
#         ...
# 75   -0.000045
# 76   -0.000043
# 77   -0.000044
# 78   -0.000043
# 79   -0.000045
# Name: x, Length: 80, dtype: float64

# %%
data = pd.read_csv("datalogging/Data/ResistivityVFrequency/ResistivityVFrequency1680137154.txt")
plt.scatter(data['f'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSwap/hallSwap1680144525.txt")
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSwap/hallSwap1680146574.txt")
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSwap/hallSwap1680147043.txt")
plt.scatter(data['i'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSwap/hallSwap1680210249.txt")
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSwap/hallSwap1680210551.txt")
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSwap/hallSwap1680211159.txt")
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSweep/hallSweep1680211824.txt")
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSweep/hallSweep1680212395.txt")
plt.scatter(data['i'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSweep/hallSweep1680212975.txt")
plt.scatter(data['i'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSwap/hallSwap1680217431.txt")
plt.scatter(data['t'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/HallSweep/hallSweep1680217879.txt")
plt.scatter(data['i'], data['x'])

# %%
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680563977.txt")
plt.scatter(data[' trueGateDC'], data[' trueGateI'])

# %%
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680566470.txt")
plt.scatter(data[' trueGateDC'], data[' trueGateI'])

# %%
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680566770.txt")
plt.scatter(data[' trueGateDC'], data[' trueGateI'])
plt.xlim(0, 10)
# Out:
# (0.0, 10.0)

# %%
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680566770.txt")
plt.scatter(data[' trueGateDC'], data['x'])

# %%
voltage = -1
resistance = 10**5
current = voltage/resistance
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680567372.txt")
plt.scatter(data[' trueGateDC'], data['x']/current)
plt.ylabel('resistance')
plt.xlabel('dc bias')
plt.title("Sample resistance vs gate bias")
# Out:
# Text(0.5, 1.0, 'Sample resistance vs gate bias')

# %%
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680567372.txt")
plt.scatter(data[' trueGateDC'], data[' trueGateI'])
plt.ylabel('dc current')
plt.xlabel('dc bias')
plt.title("Gate current vs gate bias")
# Out:
# Text(0.5, 1.0, 'Gate current vs gate bias')

# %%
voltage = -1
resistance = 10**5
current = voltage/resistance
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680569748.txt")
plt.scatter(data['trueGateDC'], data['x']/current)
plt.ylabel('resistance')
plt.xlabel('dc bias')
plt.title("Sample resistance vs gate bias")
# Out:
# Text(0.5, 1.0, 'Sample resistance vs gate bias')

# %%
voltage = -1
resistance = 10**5
current = voltage/resistance
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680569748.txt")
plt.scatter(data['trueGateDC'], data['x']/current)
plt.ylabel('resistance')
plt.xlabel('dc bias')
plt.title("Sample resistance vs gate bias")
# Out:
# Text(0.5, 1.0, 'Sample resistance vs gate bias')

# %%
voltage = -1
resistance = 10**5
current = voltage/resistance
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680569748.txt")
plt.scatter(data['trueGateDC'], data['trueGateI'])
plt.ylabel('dc current ')
plt.xlabel('dc bias')
plt.title("Sample dc current vs gate bias")
# Out:
# Text(0.5, 1.0, 'Sample dc current vs gate bias')

# %%
voltage = -1
resistance = 10**5
current = voltage/resistance
data1 = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680594238.txt")
plt.scatter(data1['trueGateDC'], data1['x']/current)
plt.ylabel('resistance')
plt.xlabel('dc bias')
plt.title("Sample resistance vs gate bias")
data1['trueGateI']
# Out:
# 0     -8.175378e-10
# 1      2.571922e-11
# 2     -1.743879e-10
# 3      4.564729e-10
# 4      5.712543e-11
#            ...
# 799   -8.704194e-10
# 800   -3.851064e-11
# 801   -1.890683e-10
# 802   -4.352028e-10
# 803    1.067668e-09
# Name: trueGateI, Length: 804, dtype: float64

# %%
plt.scatter(data1['trueGateDC'], data1['trueGateI'])
plt.xlabel("gate bias")
plt.ylabel("gate current")
# Out:
# Text(0, 0.5, 'gate current')

# %%
plt.scatter(data1['t'], data1['trueGateDC'])
plt.xlabel(" time")
plt.ylabel("gate bias")
# Out:
# Text(0, 0.5, 'gate bias')

# %%
plt.scatter(data1['trueGateDC'], data1['x']/current)
plt.xlabel("gate voltage")
plt.ylabel("resistance")
# Out:
# Text(0, 0.5, 'resistance')

# %%
data['trueGateI']
# Out:
# 0     -8.024871e-10
# 1     -3.417259e-10
# 2      3.382681e-10
# 3     -1.446845e-09
# 4      3.866900e-10
#            ...
# 754   -4.425972e-09
# 755   -4.196904e-09
# 756   -3.554891e-09
# 757   -3.954206e-09
# 758   -2.630647e-09
# Name: trueGateI, Length: 759, dtype: float64

# %%
voltage = -1
resistance = 10**5
current = voltage/resistance
data1 = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680640230.txt")
data2 = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680647818.txt")
data3 = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680649886.txt")
data4 = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680665993.txt")

dataA = pd.DataFrame.append(data1, data2)
dataB = pd.DataFrame.append(data3, data4)
data = pd.DataFrame.append(dataA, dataB)
plt.scatter(data['trueGateDC'], data['x']/current)
#plt.scatter(data1['trueGateDC'], data1['x']/current)
plt.ylabel('resistance')
plt.xlabel('dc bias')
plt.title("Sample resistance vs gate bias")
data['trueGateI']
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_6136\1612333643.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataA = pd.DataFrame.append(data1, data2)
# C:\Users\matth\AppData\Local\Temp\ipykernel_6136\1612333643.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataB = pd.DataFrame.append(data3, data4)
# C:\Users\matth\AppData\Local\Temp\ipykernel_6136\1612333643.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = pd.DataFrame.append(dataA, dataB)
# 0      -8.024871e-10
# 1      -3.417259e-10
# 2       3.382681e-10
# 3      -1.446845e-09
# 4       3.866900e-10
#             ...
# 2014   -3.020779e-09
# 2015    9.492169e-10
# 2016    9.780948e-10
# 2017   -3.182139e-09
# 2018   -1.698126e-09
# ...

# %%
plt.scatter(data['t'], data['x']/current)

# %%
plt.scatter(data['t'], data['trueGateI'])

# %%
plt.scatter(data['t'], data['trueGateDC'])

# %%
plt.scatter(data['t'], data['trueGateI'])

# %%
plt.scatter(data['trueGateDC'], data['trueGateI'])

# %%
data
# Out:
#                  t  i         x         y         r     theta  xK  tc  therm  \
# 0     1.680640e+09  0 -0.044453 -0.000444  0.044453  180.1012   0   0      0
# 1     1.680640e+09  0 -0.045184 -0.000079  0.044820  179.1729   0   0      0
# 2     1.680640e+09  0 -0.045549  0.000287  0.045915  180.0980   0   0      0
# 3     1.680640e+09  0 -0.046646 -0.000079  0.046651  180.5496   0   0      0
# 4     1.680640e+09  0 -0.047012 -0.000079  0.047012  180.0957   0   0      0
# ...            ... ..       ...       ...       ...       ...  ..  ..    ...
# 2014  1.680678e+09  0 -0.038238 -0.000444  0.038603  180.1177   0   0      0
# 2015  1.680678e+09  0 -0.038603 -0.000444  0.038603  180.1165   0   0      0
# 2016  1.680678e+09  0 -0.038969 -0.000079  0.038969  180.1154   0   0      0
# 2017  1.680678e+09  0 -0.038969 -0.000079  0.038969  180.1144   0   0      0
# 2018  1.680679e+09  0 -0.038969 -0.000444  0.039337  180.6527   0   0      0
#
#        dc  trueGateDC     trueGateI
# ...

# %%
data
# Out:
#                  t  i         x         y         r     theta  xK  tc  therm  \
# 0     1.680680e+09  0 -0.203845  0.009057  0.208810  177.1433   0   0      0
# 1     1.680680e+09  0 -0.219565  0.010884  0.221643  177.1948   0   0      0
# 2     1.680680e+09  0 -0.225414  0.011615  0.226060  177.0599   0   0      0
# 3     1.680680e+09  0 -0.228339  0.011615  0.229018  177.0927   0   0      0
# 4     1.680680e+09  0 -0.229801  0.011980  0.230498  177.0204   0   0      0
# ...            ... ..       ...       ...       ...       ...  ..  ..    ...
# 2735  1.680715e+09  0 -0.742709  0.127451  0.753565  170.2627   0   0      0
# 2736  1.680715e+09  0 -0.742709  0.127451  0.753503  170.2900   0   0      0
# 2737  1.680715e+09  0 -0.742709  0.127451  0.753503  170.2627   0   0      0
# 2738  1.680715e+09  0 -0.742709  0.127451  0.753442  170.2353   0   0      0
# 2739  1.680715e+09  0 -0.742709  0.127817  0.753565  170.2353   0   0      0
#
#          dc  trueGateDC     trueGateI
# ...

# %%
voltage = -1
resistance = 10**5
current = voltage/resistance
data = pd.read_csv("datalogging/Data/ResistivityDCBiasSMU/resistivity1680680336.txt")

plt.scatter(data['trueGateDC'][1200:2600], data['x'][1200:2600])
#plt.scatter(data1['trueGateDC'], data1['x']/current)
plt.ylabel('resistance')
plt.xlabel('dc bias')
plt.title("Sample resistance vs gate bias")
plt.xlim(-10, 10)
plt.ylim(0, -.1)
# Out:
# (0.0, -0.1)

# %%
plt.scatter(data['t'], data['x'])

# %%
plt.scatter(data['t'], data['trueGateDC'])

# %%
plt.scatter(data['t'], data['trueGateI'])

# %%
plt.scatter(data['t'], data['x'])

# %%
plt.scatter(data['trueGateDC'], data['x'])

# %%
plt.scatter(data['t'], data['x'])
plt.xlim(89650+1.6806*10**9, 89730+1.6806*10**9)
# Out:
# (1680689650.0, 1680689730.0)

# %%
plt.scatter(data['t'], data['trueGateDC'])
plt.xlim(89650+1.6806*10**9, 89730+1.6806*10**9)
# Out:
# (1680689650.0, 1680689730.0)
