# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("datalogging/Data/Resistivity/resistivity1684195618.txt")
tempData =  pd.read_csv("datalogging/Data/tempControl/pidTemp1684195144.txt")

# %%
plt.scatter(data['t'], data['x'])

# %%
plt.scatter(tempData['t'], tempData['temp_tc'])
